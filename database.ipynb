# %%
import tweepy
import time

# %%
# Claves del consumidor y tokens de acceso, utilizados para OAuth
consumer_key = 'd1txrogo10pOoDbgah9WDmyGx'
consumer_secret = 'oB5Xrnfb7wrMJLip0ZLNLO3blRgNfGuA4ZBNyzoY7KIy3v5Qya'

consumer_Owner = '_Huguez'
consumer_Owner_ID = '714880949876461568'

access_token = '714880949876461568-Jy0zkv22pLrJdxoSnWn8s31TdfRfyUI'
access_token_secret = 'AhkzMdrfk9tBawrpUYdh0vXoRRERI4BFK40ak5KbnZ3ua'

# Proceso de OAuth, utilizando las claves y los tokens
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
 

# autenticación, usando una interfaz de la api de twitter
api = tweepy.API(auth, wait_on_rate_limit=True )

public_tweets = api.home_timeline( count = 6 )

print( "Estos son los tweets de mi Time-line.\n" )
for (i, tweet) in enumerate(public_tweets):
    print( "{}: {}".format( i, tweet.text ) )
# Out:
# Estos son los tweets de mi Time-line.
#
# 0: Los insectos se revelan en contra de la separación de rastreros y voladores. ¿Cómo solucionará Doña Copechita este… https://t.co/kFiEKqb0y1
# 1: Las fotografías de Manuel Álvarez Bravo pertenecerán a la Memoria del Mundo de la @UNESCO https://t.co/bRO4wrXFcN https://t.co/bWnI6Ew1gs
# 2: HEADS UP, NYC!
#
# #UFC217 weigh-ins are FREE but TICKETED to the PUBLIC!!
#
# Reserve your spot NOW 🎟… https://t.co/iKRZZF3A7f
# 3: From #InsideStuff... @boogiecousins @Jrue_Holiday11 &amp; @aa000G9 of the @PelicansNBA talk about Halloween in the nati… https://t.co/UW8uVovjgl
# 4: En México, donde la muerte se celebra cada noviembre,  44% de la población no tiene previsto sus gastos funerarios. https://t.co/9qCcTdgmCC

# %%
def llenarTweetts( twittero, listTwitteros, nivel ):
    
    def limit_handled(cursor):
        while True:
            try:
                yield cursor.next()
            except tweepy.RateLimitError:
                time.sleep( 15*60 )
                continue
            except StopIteration:
                break

    
    # con este for recorro todos los followers de mi tweetter
    for follower in api.followers( twittero.screen_name ):

        # las cuantas que contiene menos de 300 seguinores son seleccionadas 
        if follower.friends_count < 300:
            # si le twittero no esta en el diccionario
            # continuamos con la operacion
            if not follower.protected and follower.screen_name not in listTwitteros:
                
                # incluyo los nombres como llaves en el diccionario donde
                # los valores sera una lista de todos los twitteros que siguen
                listTwitteros[ follower.screen_name ] = list()

                # lleno la lista con los twitteros
                listTwitteros[ follower.screen_name ] = [ tweet.text for tweet in api.user_timeline(follower.screen_name,count = 200 ) ]        
            # llamamos a la funcion ora ves pero con el seguidor    
            if nivel > 0:
                if not follower.protected:
                    llenarTweetts( follower, listTwitteros, nivel-1 )

# %%
bdTwitteros = {}

api = tweepy.API(auth, wait_on_rate_limit=True )

llenarTweetts( api.me(), bdTwitteros, 5 )
# Out:
# 5
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# /home/crls/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     276         try:
# --> 277             return self.connection.recv_into(*args, **kwargs)
#     278         except OpenSSL.SSL.SysCallError as e:
#
# /home/crls/anaconda3/lib/python3.5/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1546             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1547         self._raise_ssl_error(self._ssl, result)
#    1548
#
# /home/crls/anaconda3/lib/python3.5/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1352         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1353             raise WantReadError()
#    1354         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# WantReadError                             Traceback (most recent call last)
# /home/crls/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     276         try:
# --> 277             return self.connection.recv_into(*args, **kwargs)
#     278         except OpenSSL.SSL.SysCallError as e:
#
# /home/crls/anaconda3/lib/python3.5/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1546             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1547         self._raise_ssl_error(self._ssl, result)
#    1548
#
# /home/crls/anaconda3/lib/python3.5/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1352         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1353             raise WantReadError()
#    1354         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# WantReadError                             Traceback (most recent call last)
# /home/crls/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     276         try:
# --> 277             return self.connection.recv_into(*args, **kwargs)
#     278         except OpenSSL.SSL.SysCallError as e:
#
# /home/crls/anaconda3/lib/python3.5/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1546             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1547         self._raise_ssl_error(self._ssl, result)
#    1548
#
# /home/crls/anaconda3/lib/python3.5/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1352         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1353             raise WantReadError()
#    1354         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# WantReadError                             Traceback (most recent call last)
# /home/crls/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     276         try:
# --> 277             return self.connection.recv_into(*args, **kwargs)
#     278         except OpenSSL.SSL.SysCallError as e:
#
# /home/crls/anaconda3/lib/python3.5/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1546             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1547         self._raise_ssl_error(self._ssl, result)
#    1548
#
# /home/crls/anaconda3/lib/python3.5/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1352         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1353             raise WantReadError()
#    1354         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# WantReadError                             Traceback (most recent call last)
# /home/crls/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     276         try:
# --> 277             return self.connection.recv_into(*args, **kwargs)
#     278         except OpenSSL.SSL.SysCallError as e:
#
# /home/crls/anaconda3/lib/python3.5/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1546             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1547         self._raise_ssl_error(self._ssl, result)
#    1548
#
# /home/crls/anaconda3/lib/python3.5/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1352         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1353             raise WantReadError()
#    1354         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# WantReadError                             Traceback (most recent call last)
# /home/crls/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     276         try:
# --> 277             return self.connection.recv_into(*args, **kwargs)
#     278         except OpenSSL.SSL.SysCallError as e:
#
# /home/crls/anaconda3/lib/python3.5/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1546             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1547         self._raise_ssl_error(self._ssl, result)
#    1548
#
# /home/crls/anaconda3/lib/python3.5/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1352         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1353             raise WantReadError()
#    1354         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# WantReadError                             Traceback (most recent call last)
# /home/crls/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     276         try:
# --> 277             return self.connection.recv_into(*args, **kwargs)
#     278         except OpenSSL.SSL.SysCallError as e:
#
# /home/crls/anaconda3/lib/python3.5/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1546             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1547         self._raise_ssl_error(self._ssl, result)
#    1548
#
# /home/crls/anaconda3/lib/python3.5/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1352         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1353             raise WantReadError()
#    1354         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# WantReadError                             Traceback (most recent call last)
# /home/crls/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     276         try:
# --> 277             return self.connection.recv_into(*args, **kwargs)
#     278         except OpenSSL.SSL.SysCallError as e:
#
# /home/crls/anaconda3/lib/python3.5/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1546             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1547         self._raise_ssl_error(self._ssl, result)
#    1548
#
# /home/crls/anaconda3/lib/python3.5/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1352         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1353             raise WantReadError()
#    1354         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# timeout                                   Traceback (most recent call last)
# /home/crls/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/response.py in _error_catcher(self)
#     301             try:
# --> 302                 yield
#     303
#
# /home/crls/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     383                 cache_content = False
# --> 384                 data = self._fp.read(amt)
#     385                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#
# /home/crls/anaconda3/lib/python3.5/http/client.py in read(self, amt)
#     447             b = bytearray(amt)
# --> 448             n = self.readinto(b)
#     449             return memoryview(b)[:n].tobytes()
#
# /home/crls/anaconda3/lib/python3.5/http/client.py in readinto(self, b)
#     487         # (for example, reading in 1k chunks)
# --> 488         n = self.fp.readinto(b)
#     489         if not n and b:
#
# /home/crls/anaconda3/lib/python3.5/socket.py in readinto(self, b)
#     575             try:
# --> 576                 return self._sock.recv_into(b)
#     577             except timeout:
#
# /home/crls/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     292             else:
# --> 293                 return self.recv_into(*args, **kwargs)
#     294
#
# /home/crls/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     292             else:
# --> 293                 return self.recv_into(*args, **kwargs)
#     294
#
# /home/crls/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     292             else:
# --> 293                 return self.recv_into(*args, **kwargs)
#     294
#
# /home/crls/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     292             else:
# --> 293                 return self.recv_into(*args, **kwargs)
#     294
#
# /home/crls/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     292             else:
# --> 293                 return self.recv_into(*args, **kwargs)
#     294
#
# /home/crls/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     292             else:
# --> 293                 return self.recv_into(*args, **kwargs)
#     294
#
# /home/crls/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     292             else:
# --> 293                 return self.recv_into(*args, **kwargs)
#     294
#
# /home/crls/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     290             if not rd:
# --> 291                 raise timeout('The read operation timed out')
#     292             else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# /home/crls/anaconda3/lib/python3.5/site-packages/requests/models.py in generate()
#     737                 try:
# --> 738                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     739                         yield chunk
#
# /home/crls/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/response.py in stream(self, amt, decode_content)
#     435             while not is_fp_closed(self._fp):
# --> 436                 data = self.read(amt=amt, decode_content=decode_content)
#     437
#
# /home/crls/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     400                         # Content-Length are caught.
# --> 401                         raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#     402
#
# /home/crls/anaconda3/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      76             try:
# ---> 77                 self.gen.throw(type, value, traceback)
#      78                 raise RuntimeError("generator didn't stop after throw()")
#
# /home/crls/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/response.py in _error_catcher(self)
#     306                 # there is yet no clean way to get at it from this context.
# --> 307                 raise ReadTimeoutError(self._pool, None, 'Read timed out.')
#     308
#
# ReadTimeoutError: HTTPSConnectionPool(host='api.twitter.com', port=443): Read timed out.
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# /home/crls/anaconda3/lib/python3.5/site-packages/tweepy/binder.py in execute(self)
#     186                                                 auth=auth,
# --> 187                                                 proxies=self.api.proxy)
#     188                 except Exception as e:
#
# /home/crls/anaconda3/lib/python3.5/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     517         send_kwargs.update(settings)
# --> 518         resp = self.send(prep, **send_kwargs)
#     519
#
# /home/crls/anaconda3/lib/python3.5/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     671         if not stream:
# --> 672             r.content
#     673
#
# /home/crls/anaconda3/lib/python3.5/site-packages/requests/models.py in content(self)
#     815             else:
# --> 816                 self._content = bytes().join(self.iter_content(CONTENT_CHUNK_SIZE)) or bytes()
#     817
#
# /home/crls/anaconda3/lib/python3.5/site-packages/requests/models.py in generate()
#     744                 except ReadTimeoutError as e:
# --> 745                     raise ConnectionError(e)
#     746             else:
#
# ConnectionError: HTTPSConnectionPool(host='api.twitter.com', port=443): Read timed out.
#
# During handling of the above exception, another exception occurred:
#
# TweepError                                Traceback (most recent call last)
# <ipython-input-8-3105fa2862b3> in <module>()
#       4 api = tweepy.API(auth, wait_on_rate_limit=True )
#       5
# ----> 6 llenarTweetts( api.me(), bdTwitteros, 5 )
#
# <ipython-input-5-ff9a9889e453> in llenarTweetts(twittero, listTwitteros, nivel)
#      32             if nivel > 0:
#      33                 if not follower.protected:
# ---> 34                     llenarTweetts( follower, listTwitteros, nivel-1 )
#
# <ipython-input-5-ff9a9889e453> in llenarTweetts(twittero, listTwitteros, nivel)
#      27
#      28                 # lleno la lista con los twitteros
# ---> 29                 listTwitteros[ follower.screen_name ] = [ tweet.text for tweet in api.user_timeline(follower.screen_name,count = 200 ) ]
#      30             # llamamos a la funcion ora ves pero con el seguidor
#      31             print( nivel )
#
# /home/crls/anaconda3/lib/python3.5/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     243             return method
#     244         else:
# --> 245             return method.execute()
#     246
#     247     # Set pagination mode
#
# /home/crls/anaconda3/lib/python3.5/site-packages/tweepy/binder.py in execute(self)
#     187                                                 proxies=self.api.proxy)
#     188                 except Exception as e:
# --> 189                     raise TweepError('Failed to send request: %s' % e)
#     190                 rem_calls = resp.headers.get('x-rate-limit-remaining')
#     191                 if rem_calls is not None:
#
# TweepError: Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Read timed out.

# %%
#z = {**x, **y} mesclar 2 diccionarios

# que onda con este error !!!!
# Failed to parse JSON payload: Unterminated string starting at: line 1 column 675907 (char 675906)

# %%
k = 0
for i in bdTwitteros['Abraham_Baez']:
    k += len( bdTwitteros ) * len( i )
    
print( k )
